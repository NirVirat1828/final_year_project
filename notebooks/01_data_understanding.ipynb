# %% [markdown]
# # Data Understanding
# This notebook explores the raw sensor data and provides initial insights.

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load and explore data
# TODO: Load raw data from data/raw/
