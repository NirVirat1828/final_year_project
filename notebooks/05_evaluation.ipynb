# %% [markdown]
# # Model Evaluation
# This notebook evaluates trained models and compares their performance.

# %%
# Import libraries
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# Model evaluation
# TODO: Evaluate models and generate metrics
